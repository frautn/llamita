# %%
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (0.3.72)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (3.12.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (0.3.45)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: mypy_extensions>=0.3.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langsmith>=0.1.125->langchain-community) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)

# %%
# !pip install langchain-ollama
# Out:
# Requirement already satisfied: langchain-ollama in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (0.3.6)
# Requirement already satisfied: ollama<1.0.0,>=0.5.1 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-ollama) (0.5.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.70 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-ollama) (0.3.72)
# Requirement already satisfied: langsmith>=0.3.45 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-ollama) (0.3.45)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-ollama) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-ollama) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-ollama) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-ollama) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-ollama) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-ollama) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.70->langchain-ollama) (3.0.0)
# Requirement already satisfied: httpx>=0.27 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from ollama<1.0.0,>=0.5.1->langchain-ollama) (0.28.1)
# Requirement already satisfied: anyio in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.5.1->langchain-ollama) (4.9.0)
# Requirement already satisfied: certifi in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.5.1->langchain-ollama) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.5.1->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.5.1->langchain-ollama) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->ollama<1.0.0,>=0.5.1->langchain-ollama) (0.16.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-ollama) (3.11.1)
# Requirement already satisfied: requests<3,>=2 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-ollama) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-ollama) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-ollama) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-ollama) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-ollama) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-ollama) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-ollama) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /home/edg/miniconda3/envs/llamita/lib/python3.12/site-packages (from anyio->httpx>=0.27->ollama<1.0.0,>=0.5.1->langchain-ollama) (1.3.1)

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Cleaning up old version at /usr/local/lib/ollama
# [sudo] password for edg:
# ^C

# %%
# Runs Ollama service in the background
# !ollama serve &>/dev/null&

# %%
# # !ollama pull llama3.1:8b
# !ollama pull llama3.1

# %%
from langchain_ollama import ChatOllama
from IPython.display import display, Markdown, Latex

llm = ChatOllama(
    model = "llama3.1",
#    model = "llama3.1:8b",
    temperature = 0,
)

# %%
result = llm.invoke("Solve the equation: 2^(5x-1)=4^7")
display(Markdown(result.content))
# Out:
# A nice exponential equation!
#
# Let's simplify both sides:
#
# 2^(5x-1) = (2^2)^7
# = 2^(14)
#
# Now we have:
# 2^(5x-1) = 2^(14)
#
# Since the bases are equal, we can equate the exponents:
# 5x - 1 = 14
#
# Add 1 to both sides:
# 5x = 15
#
# Divide by 5:
# x = 3
#
# So, the solution is x = 3.
